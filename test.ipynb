# %% [markdown]
# <a href="https://colab.research.google.com/github/yihong1011/TibameML/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s=3
print(s)
if s>5:
    if s == 6:
        pass
    else:
        print(s)
# Out:
# 3

# %%
print(s+2)
# Out:
# 5
